# %% [markdown]
# # Assignment 5
#
# Implement Page Rank Algorithm. (Use python or beautiful soup for implementation).

# %%
import requests
from bs4 import BeautifulSoup
import networkx as nx
import pandas as pd

def get_links_from_wikipedia(url):
    response = requests.get(url)
    soup = BeautifulSoup(response.text, 'html.parser')
    links = []
    for link in soup.find_all('a', href=True):
        href = link.get('href')
        if href.startswith('/wiki/') and ':' not in href:
            links.append(href)
    return links

def build_wikipedia_graph(start_url, max_depth, max_pages):
    G = nx.DiGraph()
    to_visit = [(start_url, 0)]
    visited = set()

    while to_visit:
        current_url, depth = to_visit.pop(0)

        if current_url not in visited and depth < max_depth:
            links = get_links_from_wikipedia("https://en.wikipedia.org" + current_url)
            visited.add(current_url)

            for link in links[:max_pages]:
                G.add_edge(current_url, link)
                to_visit.append((link, depth + 1))

    return G

def calculate_pagerank(graph):
    return nx.pagerank(graph)

start_url = "/wiki/PageRank"
max_depth = 2
max_pages = 10

graph = build_wikipedia_graph(start_url, max_depth, max_pages)
pagerank = calculate_pagerank(graph)

result_df = pd.DataFrame(pagerank.items(), columns=['Page', 'PageRank Score'])
result_df = result_df.sort_values(by='PageRank Score', ascending=False)

result_df
# Out:
#                                     Page  PageRank Score
# 1                        /wiki/Main_Page        0.050940
# 7                        /wiki/Wikipedia        0.032920
# 3                    /wiki/Google_Search        0.029945
# 11    /wiki/Yugoslav_destroyer_Ljubljana        0.029799
# 8                     /wiki/Free_content        0.029799
# 9                     /wiki/Encyclopedia        0.029799
# 10                /wiki/English_language        0.029799
# 2                        /wiki/Algorithm        0.029255
# 4                          /wiki/Ranking        0.029255
# 6                    /wiki/Search_engine        0.029255
# 17                          /wiki/Google        0.026824
# 20                      /wiki/Google_Ads        0.026824
# 19                         /wiki/Revenue        0.026824
# 18               /wiki/Web_search_engine        0.026824
# 31  /wiki/Search_engine_(disambiguation)        0.026134
# 25   /wiki/Second_Place_(disambiguation)        0.026134
# 24           /wiki/Rank_(disambiguation)        0.026134
# 32   /wiki/Search_suggest_drop-down_list        0.026134
# 33                       /wiki/Web_query        0.026134
# 22                /wiki/Ranked_(musical)        0.026134
# 34                      /wiki/Search_box        0.026134
# 23               /wiki/Ranking_(surname)        0.026134
# 35                 /wiki/Software_system        0.026134
# 21  /wiki/List_of_international_rankings        0.026134
# 16                /wiki/Computer_science        0.026134
# 15                     /wiki/Mathematics        0.026134
# 14         /wiki/Greatest_common_divisor        0.026134
# 13      /wiki/Algorithm_(disambiguation)        0.026134
# 12          /wiki/Analysis_of_algorithms        0.026134
# 26                        /wiki/Web_page        0.025703
# 27                             /wiki/URL        0.025703
# 28                     /wiki/Address_bar        0.025703
# 29                  /wiki/World_Wide_Web        0.025703
# 30                     /wiki/Web_browser        0.025703
# 5                         /wiki/Webpages        0.025703
# 0                         /wiki/PageRank        0.025703
